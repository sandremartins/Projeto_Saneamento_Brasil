# %%
import pandas as pd
import numpy as np

# %%
# Import as tabelas do SNIS
data_sul = pd.read_csv("AgrupamentoDesagregado--2018-05-31--11-43-29_Regiao_Sul.csv", encoding='latin1', delimiter=';', engine='python', skipfooter = 3)
data_sudeste = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-05-11_Regiao_Sudeste.csv", encoding='latin1', delimiter=';', engine='python', skipfooter = 3)
data_norte = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-24-50_Regiao_Norte.csv", encoding='latin1', delimiter=';', engine='python', skipfooter = 3)
data_nordeste = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-49-58_Regiao_Nordeste.csv", encoding='latin1', delimiter=';', engine='python', skipfooter = 3)
data_centro_oeste = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-54-02_Regiao_centro_Oeste.csv", encoding='latin1', delimiter=';', engine='python', skipfooter = 3)

# %%
# Import as tabelas do SNIS
#data_sul = pd.read_csv("AgrupamentoDesagregado--2018-05-31--11-43-29_Regiao_Sul.csv", delimiter=';', engine='python', skipfooter = 3)
#data_sudeste = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-05-11_Regiao_Sudeste.csv", delimiter=';', engine='python', skipfooter = 3)
#data_norte = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-24-50_Regiao_Norte.csv", delimiter=';', engine='python', skipfooter = 3)
#data_nordeste = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-49-58_Regiao_Nordeste.csv", delimiter=';', engine='python', skipfooter = 3)
#data_centro_oeste = pd.read_csv("AgrupamentoDesagregado--2018-05-31--12-54-02_Regiao_centro_Oeste.csv", delimiter=';', engine='python', skipfooter = 3)

# %%
df_snis = pd.concat([data_sul, data_sudeste, data_norte, data_nordeste, data_centro_oeste])

# %%
display(df_snis.head())
# Out:
#   Código do Município        Município  Estado        Região   \
# 0               410010           Abatiá      PR  Sul
# 1               410080  Alvorada do Sul      PR  Sul
# 2               410110           Andirá      PR  Sul
# 3               410115           Ângulo      PR  Sul
# 4               410240     Bandeirantes      PR  Sul
#
#   Ano de Referência  Código do Prestador   \
# 0               2016             41001011
# 1               2016             41008011
# 2               2016             41011011
# 3               2016             41011511
# 4               2016             41024011
#
#                                           Prestador  Sigla do Prestador   \
# 0        Serviço Autônomo Municipal de Água e Esgoto               SAMAE
# 1  Serviço Autônomo de Água e Esgoto de Alvorada ...                SAAE
# 2                     Prefeitura Municipal de Andirá                 PMA
# 3        Serviço Autônomo Municipal de Água e Esgoto               SAMAE
# 4                  Serviço Autônomo de Água e Esgoto                SAAE
#
#   Abrangência  Tipo de serviço   \
# 0        Local    Água e Esgoto
# 1        Local    Água
# 2        Local    Água e Esgoto
# 3        Local    Água
# 4        Local    Água e Esgoto
#
#                                            ...                                           \
# 0                                          ...
# 1                                          ...
# 2                                          ...
# 3                                          ...
# 4                                          ...
#
#   IN076 - Incidência das análises de turbidez fora do padrão (percentual)  \
# 0                                               0,00
# 1                                               0,00
# 2                                               0,44
# 3                                               0,00
# 4                                               0,00
#
#    IN077 - Duração média dos reparos de extravasamentos de esgotos (horas/extrav.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                               1,89
# 3                                                NaN
# 4                                               4,00
#
#    IN079 - Índice de conformidade da quantidade de amostras - cloro residual (percentual)  \
# 0                                             100,00
# 1                                             100,00
# 2                                             101,32
# 3                                             118,18
# 4                                             100,00
#
#    IN080 - Índice de conformidade da quantidade de amostras - turbidez (percentual)  \
# 0                                             100,00
# 1                                             100,00
# 2                                             101,32
# 3                                             100,00
# 4                                             100,00
#
#    IN082 - Extravasamentos de esgotos por extensão de rede (extrav./Km)  \
# 0                                               0,00
# 1                                                NaN
# 2                                               0,07
# 3                                                NaN
# 4                                               0,05
#
#    IN083 - Duração média dos serviços executados (hora/serviço)  \
# 0                                               2,27
# 1                                               0,08
# 2                                               1,27
# 3                                                NaN
# 4                                               1,64
#
#    IN084 - Incidência das análises de coliformes totais fora do padrão (percentual)  \
# 0                                               0,00
# 1                                               0,00
# 2                                               0,00
# 3                                               0,00
# 4                                               0,00
#
#    IN085 - Índice de conformidade da quantidade de amostras - coliformes totais (percentual)  \
# 0                                             242,26
# 1                                             100,00
# 2                                             125,00
# 3                                             102,74
# 4                                             100,00
#
#    IN101 - Índice de suficiência de caixa (percentual)  \
# 0                                             113,25
# 1                                             135,60
# 2                                             115,92
# 3                                             111,51
# 4                                             122,22
#
#    IN102 - Índice de produtividade de pessoal total (equivalente) (ligações/empregados)
# 0                                             232,16
# 1                                             305,41
# 2                                             272,70
# 3                                             204,04
# 4                                             242,01
#
# [5 rows x 236 columns]

# %%
df_snis[['FN026 - Quantidade total de empregados próprios (Empregados)']][df_snis['Município '] == 'Campinas']
# Out:
#       FN026 - Quantidade total de empregados próprios (Empregados)
# 1307                                              2.243

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'].dtypes
# Out:
# dtype('float64')

# %%
df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'].dtypes
# Out:
# dtype('O')

# %%
df_snis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5708 entries, 0 to 439
# Columns: 236 entries, Código do Município  to IN102 - Índice de produtividade de pessoal total (equivalente) (ligações/empregados)
# dtypes: float64(26), object(210)
# memory usage: 10.3+ MB

# %%
len(df_snis)
# Out:
# 5708

# %%
# deleta linhas com municipio = ---
municipios_index_sem_id = []
# Selecione os índices dos municipios iguais a --- para remover
municipios_sem_id = df_snis[df_snis['Município '] == '---']

municipios_index_sem_id += municipios_sem_id.index.tolist()
# Remove os municipios
df_snis = df_snis.drop(municipios_index_sem_id).reset_index(drop = True)

# %%
len(df_snis)
# Out:
# 5623

# %%
df_snis['Código do Município '].dtypes
# Out:
# dtype('O')

# %%
# muda o tipo do Código do Município para int64
df_snis['Código do Município '] = df_snis['Código do Município '].str.replace('.', '')
df_snis['Código do Município '] = pd.to_numeric(df_snis['Código do Município '])
df_snis['Código do Município '].dtypes
# Out:
# dtype('int64')

# %%
df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'].dtypes
# Out:
# dtype('O')

# %%
#Alterando virgulas por pontos e transformando coluna em inteiro
df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'] = df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'].str.replace('.', '')
df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'] = pd.to_numeric(df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'])
df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'].dtypes
# Out:
# dtype('int64')

# %%
df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'].max()
# Out:
# 12038175

# %%
df_snis[df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'] == 12038175]
# Out:
#       Código do Município  Município  Estado        Região   \
# 2962                355030  São Paulo      SP  Sudeste
#
#      Ano de Referência  Código do Prestador   \
# 2962               2016             35503000
#
#                                              Prestador  Sigla do Prestador   \
# 2962  Companhia de Saneamento Básico do Estado de Sã...              SABESP
#
#      Abrangência  Tipo de serviço   \
# 2962     Regional    Água e Esgoto
#
#                                               ...                                           \
# 2962                                          ...
#
#      IN076 - Incidência das análises de turbidez fora do padrão (percentual)  \
# 2962                                               0,30
#
#       IN077 - Duração média dos reparos de extravasamentos de esgotos (horas/extrav.)  \
# 2962                                              24,87
#
#       IN079 - Índice de conformidade da quantidade de amostras - cloro residual (percentual)  \
# 2962                                             102,82
#
#       IN080 - Índice de conformidade da quantidade de amostras - turbidez (percentual)  \
# 2962                                             102,76
#
#       IN082 - Extravasamentos de esgotos por extensão de rede (extrav./Km)  \
# 2962                                               5,15
#
#       IN083 - Duração média dos serviços executados (hora/serviço)  \
# 2962                                              17,60
#
#       IN084 - Incidência das análises de coliformes totais fora do padrão (percentual)  \
# 2962                                               0,79
#
#       IN085 - Índice de conformidade da quantidade de amostras - coliformes totais (percentual)  \
# 2962                                             102,69
#
#       IN101 - Índice de suficiência de caixa (percentual)  \
# 2962                                             123,26
#
#       IN102 - Índice de produtividade de pessoal total (equivalente) (ligações/empregados)
# 2962                                             731,20
#
# [1 rows x 236 columns]

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'][df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'] == 12038175]
# Out:
# 2962    4.897
# Name: FN026 - Quantidade total de empregados próprios (Empregados), dtype: float64

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'].dtypes
# Out:
# dtype('float64')

# %%
# limpar os residuos decimais acima de 3 casas para obter o inteiro corretamente
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'] = round(df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'],3).astype(str)

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'].dtypes
# Out:
# dtype('O')

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'][df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'] == 12038175]
# Out:
# 2962    4.897
# Name: FN026 - Quantidade total de empregados próprios (Empregados), dtype: object

# %%
#Alterando virgulas por pontos e transformando coluna em inteiro
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'] = df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'].str.replace('.', '')
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'] = pd.to_numeric(df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'])
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'].dtypes
# Out:
# dtype('int64')

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'][df_snis['Município '] == 'Campinas']
# Out:
# 2462    2243
# Name: FN026 - Quantidade total de empregados próprios (Empregados), dtype: int64

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'].dtypes
# Out:
# dtype('int64')

# %%
df_snis['FN026 - Quantidade total de empregados próprios (Empregados)'][df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'] == 12038175]
# Out:
# 2962    4897
# Name: FN026 - Quantidade total de empregados próprios (Empregados), dtype: int64

# %%
#Mapeando novos valores para a coluna Tipos de Despesa
df_snis['Tipo Empresa'] = df_snis['Natureza jurídica '].map({'Autarquia': 'Pública',
                                                  'Administração pública direta': 'Pública',
                                                  'Sociedade de economia mista com administração privada': 'Pública',
                                                  'Empresa privada': 'Privada',
                                                  'Sociedade de economia mista com administração pública': 'Pública',
                                                  'Organização social': 'Pública',
                                                  'Empresa pública': 'Pública'})

# %%
#Mapeando novos valores para a coluna Tipos de Despesa
df_snis['Nat Juridica'] = df_snis['Natureza jurídica '].map({'Autarquia': 'Autarquia',
                                                  'Administração pública direta': 'APD',
                                                  'Sociedade de economia mista com administração privada': 'SEMAPriv',
                                                  'Empresa privada': 'Privada',
                                                  'Sociedade de economia mista com administração pública': 'SEMAPubl',
                                                  'Organização social': 'OS',
                                                  'Empresa pública': 'Pública'})

# %%
df_snis.groupby(['Tipo Empresa']).groups.keys()
# Out:
# dict_keys(['Privada', 'Pública'])

# %%
len(df_snis.groupby(['Tipo Empresa']).groups['Privada'])
# Out:
# 155

# %%
len(df_snis.groupby(['Tipo Empresa']).groups['Pública'])
# Out:
# 5468

# %%
#Como o pandas está tratando cada coluna do dataset
df_snis['POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)'].dtypes
# Out:
# dtype('int64')

# %%
top100 = df_snis[['Código do Município ',# Cód Município
                      'Tipo Empresa', # Tp Empresa
                      'Nat Juridica', # Nat Jurídica
                      'POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)', # Pop Total
#                      'IN046 - Índice de esgoto tratado referido à água consumida (percentual)', # Esg Tratado
                      'IN013 - Índice de perdas faturamento (percentual)', # Perdas Fat
                      'IN049 - Índice de perdas na distribuição (percentual)', # Perdas Dist
                      'IN004 - Tarifa média praticada (R$/m³)', # Tarifa méd
#                      'FN033 - Investimentos totais realizados pelo prestador de serviços (R$/ano)', # Investimento
                      'AG005 - Extensão da rede de água (km)', # Ext rede água
                      'ES004 - Extensão da rede de esgotos (km)', # Ext rede esgotos
                      'FN026 - Quantidade total de empregados próprios (Empregados)'# Empregados
                     ]]

# %%
top100.shape
# Out:
# (5623, 10)

# %%
top100 = top100.dropna()

# %%
top100.shape
# Out:
# (1938, 10)

# %%
top100 = top100.sort_values(by='POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)',ascending=False)

# %%
# foram  110 porque 5 empresas a mais para 5 municipios
top100 = top100[:200]

# %%
top100.shape
# Out:
# (200, 10)

# %%
top100.head()
# Out:
#       Código do Município  Tipo Empresa Nat Juridica  \
# 2962                355030      Pública     SEMAPubl
# 2371                330455      Pública     SEMAPubl
# 5195                530010      Pública     SEMAPubl
# 3697                292740      Pública     SEMAPubl
# 3954                230440      Pública     SEMAPubl
#
#       POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)  \
# 2962                                           12038175
# 2371                                            6498837
# 5195                                            2977216
# 3697                                            2938092
# 3954                                            2609716
#
#      IN013 - Índice de perdas faturamento (percentual)  \
# 2962                                             24,69
# 2371                                             52,41
# 5195                                             24,71
# 3697                                             44,19
# 3954                                             26,66
#
#      IN049 - Índice de perdas na distribuição (percentual)  \
# 2962                                              36,69
# 2371                                              25,36
# 5195                                              35,21
# 3697                                              53,07
# 3954                                              42,64
#
#      IN004 - Tarifa média praticada (R$/m³)  \
# 2962                                   3,66
# 2371                                   4,16
# 5195                                   4,74
# 3697                                   3,66
# 3954                                   2,99
#
#      AG005 - Extensão da rede de água (km)  \
# 2962                             21.262,00
# 2371                             10.891,20
# 5195                              8.534,49
# 3697                              5.358,67
# 3954                              4.112,66
#
#      ES004 - Extensão da rede de esgotos (km)  \
# 2962                                17.101,64
# 2371                                 4.864,51
# 5195                                 6.377,11
# 3697                                 3.506,06
# 3954                                 2.442,27
#
#       FN026 - Quantidade total de empregados próprios (Empregados)
# 2962                                               4897
# 2371                                               3105
# 5195                                               2517
# 3697                                               1447
# 3954                                               5910

# %%
top100.groupby(['Tipo Empresa']).count()
# Out:
#               Código do Município   Nat Juridica  \
# Tipo Empresa
# Privada                         19            19
# Pública                        181           181
#
#               POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)  \
# Tipo Empresa
# Privada                                                      19
# Pública                                                     181
#
#               IN013 - Índice de perdas faturamento (percentual)  \
# Tipo Empresa
# Privada                                                      19
# Pública                                                     181
#
#               IN049 - Índice de perdas na distribuição (percentual)  \
# Tipo Empresa
# Privada                                                      19
# Pública                                                     181
#
#               IN004 - Tarifa média praticada (R$/m³)  \
# Tipo Empresa
# Privada                                           19
# Pública                                          181
#
#               AG005 - Extensão da rede de água (km)  \
# Tipo Empresa
# Privada                                          19
# Pública                                         181
#
#               ES004 - Extensão da rede de esgotos (km)  \
# Tipo Empresa
# Privada                                             19
# Pública                                            181
#
#               FN026 - Quantidade total de empregados próprios (Empregados)
# Tipo Empresa
# Privada                                                      19
# Pública                                                     181

# %%
top100[top100['Código do Município '] == 355030]
# Out:
#       Código do Município  Tipo Empresa Nat Juridica  \
# 2962                355030      Pública     SEMAPubl
#
#       POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)  \
# 2962                                           12038175
#
#      IN013 - Índice de perdas faturamento (percentual)  \
# 2962                                             24,69
#
#      IN049 - Índice de perdas na distribuição (percentual)  \
# 2962                                              36,69
#
#      IN004 - Tarifa média praticada (R$/m³)  \
# 2962                                   3,66
#
#      AG005 - Extensão da rede de água (km)  \
# 2962                             21.262,00
#
#      ES004 - Extensão da rede de esgotos (km)  \
# 2962                                17.101,64
#
#       FN026 - Quantidade total de empregados próprios (Empregados)
# 2962                                               4897

# %%
#não precisa pois esta dado drop na top100 com todo o conjunto 
# top100 = top100.fillna(0)

# %%
top100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 2962 to 5608
# Data columns (total 10 columns):
# Código do Município                                                                        200 non-null int64
# Tipo Empresa                                                                               200 non-null object
# Nat Juridica                                                                               200 non-null object
# POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)    200 non-null int64
# IN013 - Índice de perdas faturamento (percentual)                                          200 non-null object
# IN049 - Índice de perdas na distribuição (percentual)                                      200 non-null object
# IN004 - Tarifa média praticada (R$/m³)                                                     200 non-null object
# AG005 - Extensão da rede de água (km)                                                      200 non-null object
# ES004 - Extensão da rede de esgotos (km)                                                   200 non-null object
# FN026 - Quantidade total de empregados próprios (Empregados)                               200 non-null int64
# dtypes: int64(3), object(7)
# memory usage: 17.2+ KB

# %%
top100.describe()
# Out:
#        Código do Município   \
# count            200.000000
# mean          335032.120000
# std            82191.200363
# min           110020.000000
# 25%           292377.500000
# 50%           340395.000000
# 75%           355130.000000
# max           530010.000000
#
#        POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)  \
# count                                       2.000000e+02
# mean                                        5.010980e+05
# std                                         1.032235e+06
# min                                         1.329340e+05
# 25%                                         1.789945e+05
# 50%                                         2.637870e+05
# 75%                                         4.305805e+05
# max                                         1.203818e+07
#
#        FN026 - Quantidade total de empregados próprios (Empregados)
# count                                         200.000000
# mean                                         2393.475000
# std                                          2003.994767
# min                                            50.000000
# 25%                                          1000.000000
# 50%                                          1625.000000
# 75%                                          3225.000000
# max                                          8980.000000

# %%
#Alterando virgulas por pontos e transformando coluna em inteiro
top100['IN013 - Índice de perdas faturamento (percentual)'] = top100['IN013 - Índice de perdas faturamento (percentual)'].str.replace(',', '.')
top100['IN013 - Índice de perdas faturamento (percentual)'] = pd.to_numeric(top100['IN013 - Índice de perdas faturamento (percentual)'])

# %%
#Alterando virgulas por pontos e transformando coluna em inteiro
top100['IN049 - Índice de perdas na distribuição (percentual)'] = top100['IN049 - Índice de perdas na distribuição (percentual)'].str.replace(',', '.')
top100['IN049 - Índice de perdas na distribuição (percentual)'] = pd.to_numeric(top100['IN049 - Índice de perdas na distribuição (percentual)'])

# %%
#Alterando virgulas por pontos e transformando coluna em inteiro
top100['IN004 - Tarifa média praticada (R$/m³)'] = top100['IN004 - Tarifa média praticada (R$/m³)'].str.replace(',', '.')
top100['IN004 - Tarifa média praticada (R$/m³)'] = pd.to_numeric(top100['IN004 - Tarifa média praticada (R$/m³)'])

# %%
#Alterando virgulas por pontos e transformando coluna em inteiro
top100['AG005 - Extensão da rede de água (km)'] = top100['AG005 - Extensão da rede de água (km)'].str.replace('.', '')
top100['AG005 - Extensão da rede de água (km)'] = top100['AG005 - Extensão da rede de água (km)'].str.replace(',', '.')
top100['AG005 - Extensão da rede de água (km)'] = pd.to_numeric(top100['AG005 - Extensão da rede de água (km)'])

# %%
#Alterando virgulas por pontos e transformando coluna em inteiro
top100['ES004 - Extensão da rede de esgotos (km)'] = top100['ES004 - Extensão da rede de esgotos (km)'].str.replace('.', '')
top100['ES004 - Extensão da rede de esgotos (km)'] = top100['ES004 - Extensão da rede de esgotos (km)'].str.replace(',', '.')
top100['ES004 - Extensão da rede de esgotos (km)'] = pd.to_numeric(top100['ES004 - Extensão da rede de esgotos (km)'])

# %%
top100.head()
# Out:
#       Código do Município  Tipo Empresa Nat Juridica  \
# 2962                355030      Pública     SEMAPubl
# 2371                330455      Pública     SEMAPubl
# 5195                530010      Pública     SEMAPubl
# 3697                292740      Pública     SEMAPubl
# 3954                230440      Pública     SEMAPubl
#
#       POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)  \
# 2962                                           12038175
# 2371                                            6498837
# 5195                                            2977216
# 3697                                            2938092
# 3954                                            2609716
#
#       IN013 - Índice de perdas faturamento (percentual)  \
# 2962                                              24.69
# 2371                                              52.41
# 5195                                              24.71
# 3697                                              44.19
# 3954                                              26.66
#
#       IN049 - Índice de perdas na distribuição (percentual)  \
# 2962                                              36.69
# 2371                                              25.36
# 5195                                              35.21
# 3697                                              53.07
# 3954                                              42.64
#
#       IN004 - Tarifa média praticada (R$/m³)  \
# 2962                                    3.66
# 2371                                    4.16
# 5195                                    4.74
# 3697                                    3.66
# 3954                                    2.99
#
#       AG005 - Extensão da rede de água (km)  \
# 2962                               21262.00
# 2371                               10891.20
# 5195                                8534.49
# 3697                                5358.67
# 3954                                4112.66
#
#       ES004 - Extensão da rede de esgotos (km)  \
# 2962                                  17101.64
# 2371                                   4864.51
# 5195                                   6377.11
# 3697                                   3506.06
# 3954                                   2442.27
#
#       FN026 - Quantidade total de empregados próprios (Empregados)
# 2962                                               4897
# 2371                                               3105
# 5195                                               2517
# 3697                                               1447
# 3954                                               5910

# %%
top100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 2962 to 5608
# Data columns (total 10 columns):
# Código do Município                                                                        200 non-null int64
# Tipo Empresa                                                                               200 non-null object
# Nat Juridica                                                                               200 non-null object
# POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)    200 non-null int64
# IN013 - Índice de perdas faturamento (percentual)                                          200 non-null float64
# IN049 - Índice de perdas na distribuição (percentual)                                      200 non-null float64
# IN004 - Tarifa média praticada (R$/m³)                                                     200 non-null float64
# AG005 - Extensão da rede de água (km)                                                      200 non-null float64
# ES004 - Extensão da rede de esgotos (km)                                                   200 non-null float64
# FN026 - Quantidade total de empregados próprios (Empregados)                               200 non-null int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 17.2+ KB

# %%
# Municipios repetidos por terem duas empresas
top100[top100.duplicated('Código do Município ')==True]
# Out:
# Empty DataFrame
# Columns: [Código do Município , Tipo Empresa, Nat Juridica, POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes), IN013 - Índice de perdas faturamento (percentual), IN049 - Índice de perdas na distribuição (percentual), IN004 - Tarifa média praticada (R$/m³), AG005 - Extensão da rede de água (km), ES004 - Extensão da rede de esgotos (km), FN026 - Quantidade total de empregados próprios (Empregados)]
# Index: []

# %%
data_tatra_brasil = pd.read_excel("Tabela_Trata_Brasil.xlsx",sheetname='Tabela Final Filtros', encoding='latin1', skiprows=3)
# Out:
# /Users/alessandremartins/anaconda/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
data_tatra_brasil.head()
# Out:
#    Código do município             Município  UF  Ranking 2018 Ranking 2017  \
# 0               351620                Franca  SP             1            1
# 1               410480              Cascavel  PR             2            8
# 2               317020            Uberlândia  MG             3            2
# 3               293330  Vitória da Conquista  BA             4           10
# 4               411520               Maringá  PR             5            5
#
#   Delta  População Total (IBGE) Operador  \
# 0     0                  344704   SABESP
# 1     6                  316226  SANEPAR
# 2    -1                  669672     DMAE
# 3     6                  346069   EMBASA
# 4     0                  403063  SANEPAR
#
#    Indicador de atendimento total de água (%)  \
# 0                                   99.970119
# 1                                   99.989881
# 2                                  100.000000
# 3                                  100.000000
# 4                                   99.989828
#
#    Nota atendimento total de água (máx. 0,5)          ...           \
# 0                                   0.499851          ...
# 1                                   0.499949          ...
# 2                                   0.500000          ...
# 3                                   0.500000          ...
# 4                                   0.499949          ...
#
#    Indicador perdas no faturamento 2015 (%)  \
# 0                                 13.006401
# 1                                 21.827482
# 2                                 24.408358
# 3                                  5.976817
# 4                                 11.668026
#
#    Indicador evolução nas perdas de faturamento (%)  \
# 0                                          2.119953
# 1                                          5.350021
# 2                                         11.634113
# 3                                        277.019557
# 4                                          0.000000
#
#    Nota evolução nas perdas de faturamento (máx. 0,25)  \
# 0                                               0.25
# 1                                               0.25
# 2                                               0.25
# 3                                               0.25
# 4                                               0.25
#
#    Indicador perdas na distribuição 2016 (%)  \
# 0                                  25.852838
# 1                                  33.533436
# 2                                  25.196395
# 3                                  19.761412
# 4                                  24.750887
#
#    Nota perdas na distribuição (máx. 0,5)  \
# 0                                0.290104
# 1                                0.223657
# 2                                0.297662
# 3                                0.379528
# 4                                0.303019
#
#    Indicador perdas na distribuição 2015 (%)  \
# 0                                  26.419016
# 1                                  34.590139
# 2                                  25.535116
# 3                                  27.621160
# 4                                  23.272393
#
#    Indicador evolução nas perdas de distribuição (%)  \
# 0                                           2.143067
# 1                                           3.054925
# 2                                           1.326491
# 3                                          28.455533
# 4                                           0.000000
#
#    Nota evolução nas perdas na distribuição (máx. 0,25)  Nota Total (máx. 10)  \
# 0                                           0.159465                 9.692003
# 1                                           0.227316                 9.276865
# 2                                           0.098704                 9.024891
# 3                                           0.250000                 8.982303
# 4                                           0.000000                 8.954230
#
#    Tarifa média (R$/m³)
# 0                  2.62
# 1                  3.54
# 2                  1.69
# 3                  2.87
# 4                  3.64
#
# [5 rows x 42 columns]

# %%
novo_trata = data_tatra_brasil[['Código do município', # Cód Município
                                'Município', # 'Município'
                                'UF', # UF
                                'Operador', # Empresa
                                'Indicador de atendimento urbano de água (%)', # At Água
                                'Indicador de atendimento urbano de esgoto (%)', # At Esgoto
                                'Indicador novas ligações de água/ligações faltantes (%)', # Novas Lig Água
                                'Indicador novas ligações de esgoto/ligações faltantes (%)', # Novas Lig Esgoto
                                'Indicador evolução nas perdas de faturamento (%)', # Ev Perdas Fat
                                'Indicador evolução nas perdas de distribuição (%)', # Ev Perdas Dist
                                'Indicador de esgoto tratado por água consumida (%)', # Esg Tratado
                                'Investimento 5 anos (Milhões R$)'# Investimento
                               ]]

# %%
novo_trata = novo_trata.round({'Indicador de atendimento urbano de água (%)':2,
                                'Indicador de atendimento urbano de esgoto (%)':2,
                                'Indicador novas ligações de água/ligações faltantes (%)':2,
                                'Indicador novas ligações de esgoto/ligações faltantes (%)':2,
                                'Indicador evolução nas perdas de faturamento (%)':2,
                                'Indicador evolução nas perdas de distribuição (%)':2,
                                'Indicador de esgoto tratado por água consumida (%)':2,
                  'Investimento 5 anos (Milhões R$)':2
                 })

# %%
novo_trata.head()
# Out:
#    Código do município             Município  UF Operador  \
# 0               351620                Franca  SP   SABESP
# 1               410480              Cascavel  PR  SANEPAR
# 2               317020            Uberlândia  MG     DMAE
# 3               293330  Vitória da Conquista  BA   EMBASA
# 4               411520               Maringá  PR  SANEPAR
#
#    Indicador de atendimento urbano de água (%)  \
# 0                                        100.0
# 1                                        100.0
# 2                                        100.0
# 3                                        100.0
# 4                                        100.0
#
#    Indicador de atendimento urbano de esgoto (%)  \
# 0                                         100.00
# 1                                         100.00
# 2                                         100.00
# 3                                          93.33
# 4                                          99.99
#
#    Indicador novas ligações de água/ligações faltantes (%)  \
# 0                                              98.52
# 1                                              99.45
# 2                                             100.00
# 3                                             100.00
# 4                                              99.30
#
#    Indicador novas ligações de esgoto/ligações faltantes (%)  \
# 0                                             100.00
# 1                                             100.00
# 2                                              37.21
# 3                                              29.15
# 4                                             100.00
#
#    Indicador evolução nas perdas de faturamento (%)  \
# 0                                              2.12
# 1                                              5.35
# 2                                             11.63
# 3                                            277.02
# 4                                              0.00
#
#    Indicador evolução nas perdas de distribuição (%)  \
# 0                                               2.14
# 1                                               3.05
# 2                                               1.33
# 3                                              28.46
# 4                                               0.00
#
#    Indicador de esgoto tratado por água consumida (%)  \
# 0                                              98.03
# 1                                              94.57
# 2                                              76.44
# 3                                              86.36
# 4                                              99.08
#
#    Investimento 5 anos (Milhões R$)
# 0                            325.99
# 1                            175.92
# 2                            266.05
# 3                            131.36
# 4                            167.95

# %%
novo_trata[novo_trata['Município'] == 'São Paulo']
# Out:
#     Código do município  Município  UF Operador  \
# 22               355030  São Paulo  SP   SABESP
#
#     Indicador de atendimento urbano de água (%)  \
# 22                                        100.0
#
#     Indicador de atendimento urbano de esgoto (%)  \
# 22                                           97.0
#
#     Indicador novas ligações de água/ligações faltantes (%)  \
# 22                                              77.37
#
#     Indicador novas ligações de esgoto/ligações faltantes (%)  \
# 22                                              57.45
#
#     Indicador evolução nas perdas de faturamento (%)  \
# 22                                               0.0
#
#     Indicador evolução nas perdas de distribuição (%)  \
# 22                                                0.0
#
#     Indicador de esgoto tratado por água consumida (%)  \
# 22                                              61.96
#
#     Investimento 5 anos (Milhões R$)
# 22                           9113.98

# %%
novo_trata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
# Código do município                                          100 non-null int64
# Município                                                    100 non-null object
# UF                                                           100 non-null object
# Operador                                                     100 non-null object
# Indicador de atendimento urbano de água (%)                  100 non-null float64
# Indicador de atendimento urbano de esgoto (%)                100 non-null float64
# Indicador novas ligações de água/ligações faltantes (%)      100 non-null float64
# Indicador novas ligações de esgoto/ligações faltantes (%)    100 non-null float64
# Indicador evolução nas perdas de faturamento (%)             100 non-null float64
# Indicador evolução nas perdas de distribuição (%)            100 non-null float64
# Indicador de esgoto tratado por água consumida (%)           100 non-null float64
# Investimento 5 anos (Milhões R$)                             100 non-null float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 9.5+ KB

# %%
novo_trata.describe()
# Out:
#        Código do município  Indicador de atendimento urbano de água (%)  \
# count           100.000000                                   100.000000
# mean         329946.100000                                    93.479000
# std           91034.404687                                    13.003894
# min          110020.000000                                    30.100000
# 25%          287935.000000                                    91.675000
# 50%          330500.000000                                    99.550000
# 75%          355227.500000                                   100.000000
# max          530010.000000                                   100.000000
#
#        Indicador de atendimento urbano de esgoto (%)  \
# count                                     100.000000
# mean                                       68.365000
# std                                        28.951447
# min                                         0.750000
# 25%                                        45.507500
# 50%                                        75.175000
# 75%                                        94.195000
# max                                       100.000000
#
#        Indicador novas ligações de água/ligações faltantes (%)  \
# count                                         100.000000
# mean                                           53.356200
# std                                            39.282254
# min                                             0.000000
# 25%                                            13.180000
# 50%                                            54.215000
# 75%                                            98.850000
# max                                           100.000000
#
#        Indicador novas ligações de esgoto/ligações faltantes (%)  \
# count                                         100.000000
# mean                                           26.530700
# std                                            32.245307
# min                                             0.000000
# 25%                                             3.367500
# 50%                                            12.895000
# 75%                                            35.767500
# max                                           100.000000
#
#        Indicador evolução nas perdas de faturamento (%)  \
# count                                        100.000000
# mean                                          13.537700
# std                                           52.961792
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            5.462500
# max                                          430.860000
#
#        Indicador evolução nas perdas de distribuição (%)  \
# count                                         100.000000
# mean                                            4.141800
# std                                             9.285201
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             4.705000
# max                                            69.350000
#
#        Indicador de esgoto tratado por água consumida (%)  \
# count                                         100.000000
# mean                                           50.833000
# std                                            31.508344
# min                                             0.000000
# 25%                                            24.692500
# 50%                                            52.370000
# 75%                                            76.567500
# max                                           100.000000
#
#        Investimento 5 anos (Milhões R$)
# count                        100.000000
# mean                         337.088400
# std                          931.886446
# min                            0.000000
# 25%                           78.980000
# 50%                          160.855000
# 75%                          294.125000
# max                         9113.980000

# %%
len(novo_trata['Município'].unique())
# Out:
# 100

# %%
data_tatra_brasil['Código do município'].head()
# Out:
# 0    351620
# 1    410480
# 2    317020
# 3    293330
# 4    411520
# Name: Código do município, dtype: int64

# %%
novo_trata['Código do município'].dtypes
# Out:
# dtype('int64')

# %%
novo_trata['Código do município'].dtypes
# Out:
# dtype('int64')

# %%
top100['Código do Município '].dtypes
# Out:
# dtype('int64')

# %%
novo_trata['Código do município'].dtypes
# Out:
# dtype('int64')

# %%
novo_trata[novo_trata['Código do município'] == 330455]
# Out:
#     Código do município       Município  UF       Operador  \
# 38               330455  Rio de Janeiro  RJ  CEDAE / FABZO
#
#     Indicador de atendimento urbano de água (%)  \
# 38                                         99.0
#
#     Indicador de atendimento urbano de esgoto (%)  \
# 38                                          85.16
#
#     Indicador novas ligações de água/ligações faltantes (%)  \
# 38                                              58.78
#
#     Indicador novas ligações de esgoto/ligações faltantes (%)  \
# 38                                              17.29
#
#     Indicador evolução nas perdas de faturamento (%)  \
# 38                                              0.84
#
#     Indicador evolução nas perdas de distribuição (%)  \
# 38                                                3.9
#
#     Indicador de esgoto tratado por água consumida (%)  \
# 38                                              44.51
#
#     Investimento 5 anos (Milhões R$)
# 38                           1922.68

# %%
cod_municipios = novo_trata['Código do município']

# %%
cod_municipios.head()
# Out:
# 0    351620
# 1    410480
# 2    317020
# 3    293330
# 4    411520
# Name: Código do município, dtype: int64

# %%
top100['Código do Município '].head()
# Out:
# 2962    355030
# 2371    330455
# 5195    530010
# 3697    292740
# 3954    230440
# Name: Código do Município , dtype: int64

# %%
top100['Código do Município '].dtypes
# Out:
# dtype('int64')

# %%
#Visualizando tamanho do dataset
top100.shape
# Out:
# (200, 10)

# %%
# df_colunas = df.columns
top100_colunas = pd.DataFrame(top100.columns, columns=['colunas'])

# %%
trata_colunas = pd.DataFrame(novo_trata.columns, columns=['colunas'])

# %%
top100_colunas
# Out:
#                                              colunas
# 0                               Código do Município
# 1                                       Tipo Empresa
# 2                                       Nat Juridica
# 3  POP_TOT - População total do município do ano ...
# 4  IN013 - Índice de perdas faturamento (percentual)
# 5  IN049 - Índice de perdas na distribuição (perc...
# 6             IN004 - Tarifa média praticada (R$/m³)
# 7              AG005 - Extensão da rede de água (km)
# 8           ES004 - Extensão da rede de esgotos (km)
# 9  FN026 - Quantidade total de empregados próprio...

# %%
trata_colunas
# Out:
#                                               colunas
# 0                                 Código do município
# 1                                           Município
# 2                                                  UF
# 3                                            Operador
# 4         Indicador de atendimento urbano de água (%)
# 5       Indicador de atendimento urbano de esgoto (%)
# 6   Indicador novas ligações de água/ligações falt...
# 7   Indicador novas ligações de esgoto/ligações fa...
# 8    Indicador evolução nas perdas de faturamento (%)
# 9   Indicador evolução nas perdas de distribuição (%)
# 10  Indicador de esgoto tratado por água consumida...
# 11                   Investimento 5 anos (Milhões R$)

# %% [markdown]
# - At água - Indicador de atendimento urbano de água (%)
# - At esgoto - Indicador de atendimento urbano de esgoto (%)
# - Esgoto tratado - Indicador de esgoto tratado por água consumida (%)
# - Novas lig água - Indicador novas ligações de água/ligações faltantes (%)
# - Novas lig esgoto - Indicador novas ligações de esgoto/ligações faltantes (%)
# - Ev perdas fat - Indicador evolução nas perdas de faturamento (%)
# - Ev perdas dist - Indicador evolução nas perdas de distribuição (%)
# - Perdas fat - Indicador perdas no faturamento 2016 (%)
# - Perdas dist - Indicador perdas na distribuição 2016 (%)
# - Tarifa méd - Tarifa média (Real/m³)
# - Investimento - Investimento
# - Ext rede água - Extensão rede de água
# - Ext rede esgotos - Extensão rede de esgotos
# - N func - N de funcionários

# %%
#data_tatra_brasil['Código do município']
top100['Código do município'] = top100['Código do Município ']

# %%
top100['Código do município'].dtypes
# Out:
# dtype('int64')

# %%
novo_trata['Código do município'].dtypes
# Out:
# dtype('int64')

# %%
type(top100)
# Out:
# pandas.core.frame.DataFrame

# %%
type(novo_trata)
# Out:
# pandas.core.frame.DataFrame

# %%
novo_trata
# Out:
#     Código do município                Município  UF         Operador  \
# 0                351620                   Franca  SP           SABESP
# 1                410480                 Cascavel  PR          SANEPAR
# 2                317020               Uberlândia  MG             DMAE
# 3                293330     Vitória da Conquista  BA           EMBASA
# 4                411520                  Maringá  PR          SANEPAR
# 5                352690                  Limeira  SP              BRK
# 6                354990      São José dos Campos  SP           SABESP
# 7                355410                  Taubaté  SP           SABESP
# 8                354980    São José do Rio Preto  SP            SEMAE
# 9                317010                  Uberaba  MG            CODAU
# 10               250400           Campina Grande  PB           CAGEPA
# 11               354850                   Santos  SP           SABESP
# 12               411370                 Londrina  PR          SANEPAR
# 13               411990             Ponta Grossa  PR          SANEPAR
# 14               261110                Petrolina  PE          COMPESA
# 15               353870               Piracicaba  SP            SEMAE
# 16               410690                 Curitiba  PR          SANEPAR
# 17               350950                 Campinas  SP           SANASA
# 18               330330                  Niterói  RJ              CAN
# 19               352590                  Jundiaí  SP              DAE
# 20               354340           Ribeirão Preto  SP            DAERP
# 21               355220                 Sorocaba  SP             SAAE
# 22               355030                São Paulo  SP           SABESP
# 23               520870                  Goiânia  GO          SANEAGO
# 24               352940                     Mauá  SP        SAMA/ BRK
# 25               500270             Campo Grande  MS               AG
# 26               330390               Petrópolis  RJ              CAI
# 27               355250                   Suzano  SP           SABESP
# 28               354100             Praia Grande  SP           SABESP
# 29               310620           Belo Horizonte  MG           COPASA
# ..                  ...                      ...  ..              ...
# 70               320520               Vila Velha  ES            CESAN
# 71               230370                  Caucaia  CE           CAGECE
# 72               352310          Itaquaquecetuba  SP           SABESP
# 73               270430                   Maceió  AL            CASAL
# 74               350600                    Bauru  SP              DAE
# 75               211130                 São Luís  MA            CAEMA
# 76               261160                   Recife  PE          COMPESA
# 77               520140     Aparecida de Goiânia  GO          SANEAGO
# 78               240810                    Natal  RN            CAERN
# 79               260960                   Olinda  PE          COMPESA
# 80               420910                Joinville  SC              CAJ
# 81               430460                   Canoas  RS           CORSAN
# 82               431440                  Pelotas  RS            SANEP
# 83               221100                 Teresina  PI         AGESPISA
# 84               260790  Jaboatão dos Guararapes  PE          COMPESA
# 85               330045             Belford Roxo  RJ            CEDAE
# 86               320130                Cariacica  ES            CESAN
# 87               330510       São João de Meriti  RJ            CEDAE
# 88               510840            Várzea Grande  MT        MUNICÍPIO
# 89               120040               Rio Branco  AC           DEPASA
# 90               430920                 Gravataí  RS           CORSAN
# 91               330170          Duque de Caxias  RJ            CEDAE
# 92               330350              Nova Iguaçu  RJ            CEDAE
# 93               330490              São Gonçalo  RJ            CEDAE
# 94               160030                   Macapá  AP            CAESA
# 95               130260                   Manaus  AM               MA
# 96               150680                 Santarém  PA    COSANPA / PMS
# 97               150140                    Belém  PA  COSANPA / SAAEB
# 98               150080               Ananindeua  PA          COSANPA
# 99               110020              Porto Velho  RO            CAERD
#
#     Indicador de atendimento urbano de água (%)  \
# 0                                         100.0
# 1                                         100.0
# 2                                         100.0
# 3                                         100.0
# 4                                         100.0
# 5                                         100.0
# 6                                         100.0
# 7                                         100.0
# 8                                         100.0
# 9                                         100.0
# 10                                        100.0
# 11                                        100.0
# 12                                        100.0
# 13                                        100.0
# 14                                        100.0
# 15                                        100.0
# 16                                        100.0
# 17                                         99.6
# 18                                        100.0
# 19                                         99.5
# 20                                         99.7
# 21                                         99.5
# 22                                        100.0
# 23                                        100.0
# 24                                         98.1
# 25                                         99.8
# 26                                         95.6
# 27                                        100.0
# 28                                         91.7
# 29                                         95.0
# ..                                          ...
# 70                                         97.7
# 71                                         75.6
# 72                                         98.7
# 73                                         96.2
# 74                                         99.9
# 75                                         87.0
# 76                                         83.8
# 77                                         76.1
# 78                                         91.6
# 79                                         96.9
# 80                                         98.9
# 81                                        100.0
# 82                                         99.8
# 83                                         99.5
# 84                                         75.8
# 85                                         78.1
# 86                                         90.2
# 87                                         93.6
# 88                                         97.0
# 89                                         59.5
# 90                                        100.0
# 91                                         86.4
# 92                                         93.8
# 93                                         84.1
# 94                                         39.4
# 95                                         88.2
# 96                                         71.5
# 97                                         71.0
# 98                                         30.1
# 99                                         36.3
#
#     Indicador de atendimento urbano de esgoto (%)  \
# 0                                          100.00
# 1                                          100.00
# 2                                          100.00
# 3                                           93.33
# 4                                           99.99
# 5                                          100.00
# 6                                           99.35
# 7                                           99.17
# 8                                          100.00
# 9                                           99.50
# 10                                          93.90
# 11                                          99.95
# 12                                          99.99
# 13                                          99.99
# 14                                          96.19
# 15                                         100.00
# 16                                          99.99
# 17                                          92.46
# 18                                          94.78
# 19                                          99.50
# 20                                          98.28
# 21                                          97.10
# 22                                          97.00
# 23                                          91.61
# 24                                          92.37
# 25                                          78.90
# 26                                          87.24
# 27                                          93.28
# 28                                          70.52
# 29                                          92.49
# ..                                            ...
# 70                                          47.97
# 71                                          34.91
# 72                                          66.89
# 73                                          40.35
# 74                                          98.80
# 75                                          50.55
# 76                                          41.67
# 77                                          24.96
# 78                                          38.17
# 79                                          45.29
# 80                                          30.94
# 81                                          30.25
# 82                                          63.29
# 83                                          24.92
# 84                                          19.37
# 85                                          39.80
# 86                                          32.68
# 87                                          62.00
# 88                                          29.73
# 89                                          23.96
# 90                                          29.23
# 91                                          44.44
# 92                                          45.58
# 93                                          38.11
# 94                                           9.04
# 95                                          10.23
# 96                                           5.86
# 97                                          12.73
# 98                                           0.75
# 99                                           3.38
#
#     Indicador novas ligações de água/ligações faltantes (%)  \
# 0                                               98.52
# 1                                               99.45
# 2                                              100.00
# 3                                              100.00
# 4                                               99.30
# 5                                               27.89
# 6                                              100.00
# 7                                              100.00
# 8                                               57.91
# 9                                               95.58
# 10                                              99.77
# 11                                              98.70
# 12                                              98.38
# 13                                              99.68
# 14                                             100.00
# 15                                             100.00
# 16                                             100.00
# 17                                              50.35
# 18                                             100.00
# 19                                              46.37
# 20                                              53.50
# 21                                              60.74
# 22                                              77.37
# 23                                              89.19
# 24                                              42.60
# 25                                              93.75
# 26                                              65.66
# 27                                             100.00
# 28                                              18.06
# 29                                               5.23
# ..                                                ...
# 70                                              51.03
# 71                                              13.43
# 72                                              69.75
# 73                                               0.00
# 74                                              49.16
# 75                                              42.72
# 76                                               0.00
# 77                                              15.43
# 78                                              16.25
# 79                                               0.00
# 80                                              60.88
# 81                                             100.00
# 82                                               0.00
# 83                                              90.20
# 84                                               0.00
# 85                                               0.00
# 86                                              12.43
# 87                                               0.00
# 88                                              19.46
# 89                                               2.17
# 90                                              25.38
# 91                                               0.00
# 92                                               0.00
# 93                                               1.09
# 94                                               3.60
# 95                                              23.20
# 96                                               9.41
# 97                                               0.00
# 98                                               2.52
# 99                                              11.28
#
#     Indicador novas ligações de esgoto/ligações faltantes (%)  \
# 0                                              100.00
# 1                                              100.00
# 2                                               37.21
# 3                                               29.15
# 4                                              100.00
# 5                                               58.70
# 6                                               80.82
# 7                                               68.75
# 8                                               40.08
# 9                                              100.00
# 10                                              23.13
# 11                                             100.00
# 12                                             100.00
# 13                                             100.00
# 14                                              23.83
# 15                                             100.00
# 16                                             100.00
# 17                                              37.42
# 18                                              17.47
# 19                                             100.00
# 20                                             100.00
# 21                                              60.95
# 22                                              57.45
# 23                                              40.19
# 24                                              50.82
# 25                                              18.06
# 26                                              36.75
# 27                                              29.99
# 28                                              17.05
# 29                                              26.31
# ..                                                ...
# 70                                               3.21
# 71                                               6.12
# 72                                               6.29
# 73                                              12.72
# 74                                               0.00
# 75                                               3.59
# 76                                               0.00
# 77                                               3.10
# 78                                               1.30
# 79                                               0.00
# 80                                               0.90
# 81                                               4.46
# 82                                               0.00
# 83                                               6.48
# 84                                               9.68
# 85                                               0.09
# 86                                               0.69
# 87                                               0.00
# 88                                               1.24
# 89                                               0.00
# 90                                               2.60
# 91                                               0.42
# 92                                               0.00
# 93                                               0.13
# 94                                               3.42
# 95                                               0.35
# 96                                               4.38
# 97                                               0.00
# 98                                               0.00
# 99                                               0.00
#
#     Indicador evolução nas perdas de faturamento (%)  \
# 0                                               2.12
# 1                                               5.35
# 2                                              11.63
# 3                                             277.02
# 4                                               0.00
# 5                                               4.23
# 6                                               0.00
# 7                                               7.81
# 8                                              25.35
# 9                                              10.81
# 10                                            119.60
# 11                                              0.00
# 12                                              0.00
# 13                                              0.00
# 14                                              4.94
# 15                                              0.00
# 16                                              0.00
# 17                                              0.00
# 18                                              0.00
# 19                                              0.00
# 20                                              0.00
# 21                                              4.53
# 22                                              0.00
# 23                                              0.00
# 24                                              0.00
# 25                                              5.80
# 26                                             51.23
# 27                                              0.00
# 28                                            430.86
# 29                                              0.00
# ..                                               ...
# 70                                              0.00
# 71                                             20.91
# 72                                              0.00
# 73                                              0.00
# 74                                              0.00
# 75                                              5.28
# 76                                              0.00
# 77                                              2.25
# 78                                             11.51
# 79                                              0.00
# 80                                              1.62
# 81                                              0.00
# 82                                              0.00
# 83                                              0.00
# 84                                              8.70
# 85                                              0.25
# 86                                              1.37
# 87                                              0.47
# 88                                              2.41
# 89                                              1.83
# 90                                              2.63
# 91                                              0.36
# 92                                              0.00
# 93                                              0.00
# 94                                              2.68
# 95                                              1.75
# 96                                              0.00
# 97                                              0.00
# 98                                              0.00
# 99                                              0.00
#
#     Indicador evolução nas perdas de distribuição (%)  \
# 0                                                2.14
# 1                                                3.05
# 2                                                1.33
# 3                                               28.46
# 4                                                0.00
# 5                                                2.35
# 6                                                1.25
# 7                                                6.68
# 8                                                6.09
# 9                                                9.17
# 10                                              20.09
# 11                                               0.00
# 12                                               0.00
# 13                                               0.00
# 14                                               9.19
# 15                                               0.00
# 16                                               0.00
# 17                                               0.00
# 18                                               0.00
# 19                                               0.00
# 20                                               0.00
# 21                                               0.84
# 22                                               0.00
# 23                                               0.00
# 24                                               0.00
# 25                                               0.00
# 26                                               0.00
# 27                                               0.00
# 28                                               0.00
# 29                                               1.55
# ..                                                ...
# 70                                               0.00
# 71                                               9.49
# 72                                               0.00
# 73                                               0.00
# 74                                               0.00
# 75                                               5.29
# 76                                               0.00
# 77                                               2.67
# 78                                               1.19
# 79                                               0.00
# 80                                               0.92
# 81                                               0.00
# 82                                              23.26
# 83                                               8.00
# 84                                               2.92
# 85                                               0.65
# 86                                               0.00
# 87                                               7.47
# 88                                               3.12
# 89                                               1.89
# 90                                               0.00
# 91                                               4.61
# 92                                               0.00
# 93                                               0.00
# 94                                               4.18
# 95                                               4.42
# 96                                               0.00
# 97                                               0.00
# 98                                               0.00
# 99                                               0.00
#
#     Indicador de esgoto tratado por água consumida (%)  \
# 0                                               98.03
# 1                                               94.57
# 2                                               76.44
# 3                                               86.36
# 4                                               99.08
# 5                                              100.00
# 6                                               92.20
# 7                                               91.11
# 8                                               87.57
# 9                                               60.79
# 10                                              99.89
# 11                                              97.63
# 12                                              89.23
# 13                                              86.71
# 14                                              67.81
# 15                                             100.00
# 16                                              92.93
# 17                                              67.98
# 18                                             100.00
# 19                                             100.00
# 20                                              89.23
# 21                                              76.95
# 22                                              61.96
# 23                                              67.88
# 24                                              67.45
# 25                                              58.38
# 26                                             100.00
# 27                                              54.02
# 28                                              65.91
# 29                                              72.16
# ..                                                ...
# 70                                              46.19
# 71                                              35.52
# 72                                               7.35
# 73                                              92.09
# 74                                               3.44
# 75                                              11.04
# 76                                              73.75
# 77                                              27.44
# 78                                              29.00
# 79                                              51.55
# 80                                              22.96
# 81                                              36.24
# 82                                              19.20
# 83                                              14.63
# 84                                              13.62
# 85                                              33.91
# 86                                              22.90
# 87                                               0.00
# 88                                              35.39
# 89                                              34.25
# 90                                              13.59
# 91                                               3.89
# 92                                               0.00
# 93                                              13.08
# 94                                              16.87
# 95                                              23.80
# 96                                               1.39
# 97                                               2.67
# 98                                               0.91
# 99                                               1.54
#
#     Investimento 5 anos (Milhões R$)
# 0                             325.99
# 1                             175.92
# 2                             266.05
# 3                             131.36
# 4                             167.95
# 5                              82.07
# 6                             380.51
# 7                              62.53
# 8                             186.41
# 9                             136.78
# 10                             23.88
# 11                            108.45
# 12                            296.32
# 13                            109.16
# 14                            159.93
# 15                            224.86
# 16                            693.76
# 17                            551.41
# 18                            158.77
# 19                            235.30
# 20                            171.74
# 21                             59.93
# 22                           9113.98
# 23                            711.94
# 24                            270.49
# 25                            647.95
# 26                             54.46
# 27                            139.32
# 28                            495.73
# 29                           1061.72
# ..                               ...
# 70                            142.68
# 71                            128.91
# 72                             93.87
# 73                            122.99
# 74                             69.58
# 75                            260.06
# 76                           1393.21
# 77                            275.63
# 78                            211.28
# 79                             62.97
# 80                            227.71
# 81                             75.21
# 82                              8.10
# 83                             47.57
# 84                             59.31
# 85                             45.57
# 86                             88.86
# 87                             38.17
# 88                              0.00
# 89                             90.57
# 90                             46.13
# 91                             78.20
# 92                            160.83
# 93                             83.07
# 94                             52.86
# 95                            293.71
# 96                            206.06
# 97                            287.26
# 98                             16.52
# 99                             15.32
#
# [100 rows x 12 columns]

# %%
tabela_limpa = pd.merge(top100, novo_trata, on='Código do município', how='inner')

# %%
tabela_limpa.shape
# Out:
# (95, 22)

# %%
tabela_limpa.head()
# Out:
#    Código do Município  Tipo Empresa Nat Juridica  \
# 0                355030      Pública     SEMAPubl
# 1                330455      Pública     SEMAPubl
# 2                530010      Pública     SEMAPubl
# 3                292740      Pública     SEMAPubl
# 4                230440      Pública     SEMAPubl
#
#    POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes)  \
# 0                                           12038175
# 1                                            6498837
# 2                                            2977216
# 3                                            2938092
# 4                                            2609716
#
#    IN013 - Índice de perdas faturamento (percentual)  \
# 0                                              24.69
# 1                                              52.41
# 2                                              24.71
# 3                                              44.19
# 4                                              26.66
#
#    IN049 - Índice de perdas na distribuição (percentual)  \
# 0                                              36.69
# 1                                              25.36
# 2                                              35.21
# 3                                              53.07
# 4                                              42.64
#
#    IN004 - Tarifa média praticada (R$/m³)  \
# 0                                    3.66
# 1                                    4.16
# 2                                    4.74
# 3                                    3.66
# 4                                    2.99
#
#    AG005 - Extensão da rede de água (km)  \
# 0                               21262.00
# 1                               10891.20
# 2                                8534.49
# 3                                5358.67
# 4                                4112.66
#
#    ES004 - Extensão da rede de esgotos (km)  \
# 0                                  17101.64
# 1                                   4864.51
# 2                                   6377.11
# 3                                   3506.06
# 4                                   2442.27
#
#    FN026 - Quantidade total de empregados próprios (Empregados)  \
# 0                                               4897
# 1                                               3105
# 2                                               2517
# 3                                               1447
# 4                                               5910
#
#                  ...                 UF       Operador  \
# 0                ...                 SP         SABESP
# 1                ...                 RJ  CEDAE / FABZO
# 2                ...                 DF          CAESB
# 3                ...                 BA         EMBASA
# 4                ...                 CE         CAGECE
#
#   Indicador de atendimento urbano de água (%)  \
# 0                                       100.0
# 1                                        99.0
# 2                                        99.1
# 3                                        90.6
# 4                                        83.3
#
#   Indicador de atendimento urbano de esgoto (%)  \
# 0                                         97.00
# 1                                         85.16
# 2                                         85.23
# 3                                         78.77
# 4                                         49.68
#
#    Indicador novas ligações de água/ligações faltantes (%)  \
# 0                                              77.37
# 1                                              58.78
# 2                                              68.48
# 3                                              18.01
# 4                                               5.61
#
#    Indicador novas ligações de esgoto/ligações faltantes (%)  \
# 0                                              57.45
# 1                                              17.29
# 2                                              12.41
# 3                                              14.92
# 4                                               7.77
#
#    Indicador evolução nas perdas de faturamento (%)  \
# 0                                              0.00
# 1                                              0.84
# 2                                              0.88
# 3                                             25.82
# 4                                             14.36
#
#    Indicador evolução nas perdas de distribuição (%)  \
# 0                                               0.00
# 1                                               3.90
# 2                                               0.00
# 3                                               0.00
# 4                                               6.78
#
#    Indicador de esgoto tratado por água consumida (%)  \
# 0                                              61.96
# 1                                              44.51
# 2                                              84.42
# 3                                             100.00
# 4                                              53.19
#
#    Investimento 5 anos (Milhões R$)
# 0                           9113.98
# 1                           1922.68
# 2                            878.80
# 3                            544.32
# 4                            806.14
#
# [5 rows x 22 columns]

# %%
#tabela_limpa = novo_trata.merge(novo_top100, left_on='Código do município', right_on='Código do Município ', how='outer')

# %%
tabela_limpa[tabela_limpa.duplicated('Código do município')==True]
# Out:
# Empty DataFrame
# Columns: [Código do Município , Tipo Empresa, Nat Juridica, POP_TOT - População total do município do ano de referência (Fonte: IBGE): (Habitantes), IN013 - Índice de perdas faturamento (percentual), IN049 - Índice de perdas na distribuição (percentual), IN004 - Tarifa média praticada (R$/m³), AG005 - Extensão da rede de água (km), ES004 - Extensão da rede de esgotos (km), FN026 - Quantidade total de empregados próprios (Empregados), Código do município, Município, UF, Operador, Indicador de atendimento urbano de água (%), Indicador de atendimento urbano de esgoto (%), Indicador novas ligações de água/ligações faltantes (%), Indicador novas ligações de esgoto/ligações faltantes (%), Indicador evolução nas perdas de faturamento (%), Indicador evolução nas perdas de distribuição (%), Indicador de esgoto tratado por água consumida (%), Investimento 5 anos (Milhões R$)]
# Index: []
#
# [0 rows x 22 columns]

# %%
len(tabela_limpa)
# Out:
# 95

# %%
#  Renomear colunas
tabela_limpa.columns = ['Cód Município',
                        'Tp Empresa', 
                        'Nat Jurídica',
                        'Pop Total',
                        'Perdas Fat',
                        'Perdas Dist',
                        'Tarifa méd',
                        'Ext rede água',
                        'Ext rede esgotos',
                        'Empregados',
                        'Código do município',
                        'Município',
                        'UF',
                        'Empresa',
                        'At Água',
                        'At Esgoto',
                        'Novas Lig Água',
                        'Novas Lig Esgoto',
                        'Ev Perdas Fat',
                        'Ev Perdas Dist',
                        'Esg Tratado',
                        'Investimento'
             ]

# %%
tabela_limpa.head()
# Out:
#    Cód Município Tp Empresa Nat Jurídica  Pop Total  Perdas Fat  Perdas Dist  \
# 0         355030    Pública     SEMAPubl   12038175       24.69        36.69
# 1         330455    Pública     SEMAPubl    6498837       52.41        25.36
# 2         530010    Pública     SEMAPubl    2977216       24.71        35.21
# 3         292740    Pública     SEMAPubl    2938092       44.19        53.07
# 4         230440    Pública     SEMAPubl    2609716       26.66        42.64
#
#    Tarifa méd  Ext rede água  Ext rede esgotos  Empregados      ...       UF  \
# 0        3.66       21262.00          17101.64        4897      ...       SP
# 1        4.16       10891.20           4864.51        3105      ...       RJ
# 2        4.74        8534.49           6377.11        2517      ...       DF
# 3        3.66        5358.67           3506.06        1447      ...       BA
# 4        2.99        4112.66           2442.27        5910      ...       CE
#
#          Empresa At Água At Esgoto  Novas Lig Água  Novas Lig Esgoto  \
# 0         SABESP   100.0     97.00           77.37             57.45
# 1  CEDAE / FABZO    99.0     85.16           58.78             17.29
# 2          CAESB    99.1     85.23           68.48             12.41
# 3         EMBASA    90.6     78.77           18.01             14.92
# 4         CAGECE    83.3     49.68            5.61              7.77
#
#    Ev Perdas Fat  Ev Perdas Dist  Esg Tratado  Investimento
# 0           0.00            0.00        61.96       9113.98
# 1           0.84            3.90        44.51       1922.68
# 2           0.88            0.00        84.42        878.80
# 3          25.82            0.00       100.00        544.32
# 4          14.36            6.78        53.19        806.14
#
# [5 rows x 22 columns]

# %%
tabela_limpa[tabela_limpa['Município']=='São Paulo']
# Out:
#    Cód Município Tp Empresa Nat Jurídica  Pop Total  Perdas Fat  Perdas Dist  \
# 0         355030    Pública     SEMAPubl   12038175       24.69        36.69
#
#    Tarifa méd  Ext rede água  Ext rede esgotos  Empregados      ...       UF  \
# 0        3.66        21262.0          17101.64        4897      ...       SP
#
#   Empresa At Água At Esgoto  Novas Lig Água  Novas Lig Esgoto  Ev Perdas Fat  \
# 0  SABESP   100.0      97.0           77.37             57.45            0.0
#
#    Ev Perdas Dist  Esg Tratado  Investimento
# 0             0.0        61.96       9113.98
#
# [1 rows x 22 columns]

# %%
#Criando novo dataset com os dados limpos
tabela_limpa.to_csv('dados_limpos_saneamento.csv', index=False)
